# %% [markdown]
# # Problem Statement

# %% [markdown]
# The market for used cars has witnessed a significant surge in demand in recent times, surpassing that of new cars. Consequently, pricing strategies for pre-owned vehicles have become crucial for businesses to remain competitive in the market. The value of a used car is influenced by a multitude of factors, such as mileage, make, model, and year of production. It is imperative for industry players to consider these variables while determining the actual worth of a used car.
# 	The objective of this statistical analysis is to demonstrate the importance of using descriptive and inferential statistics. Explore the dataset and answer various research questions to draw meaningful conclusions from data and make informed decisions using Python.
#
# 	The findings of this analysis can yield valuable insights into the determinants that inform a pricing model capable of accurately forecasting the value of pre-owned vehicles. Such insights can be leveraged by businesses to formulate profitable strategies that leverage differential pricing methodologies.

# %% [markdown]
# ### DATA INFO

# %% [markdown]
# The dataset contains 7906 rows, and 16 columns, representing various attributes of each car as follows:
#
# 1.	Sales_ID: Serial Number of
# 2.	Name: Name of the car which includes Brand name and Model name.
# 3.	Year: Manufacturing year of the car.
# 4.	Price: The price of the used car in INR Lakhs (1 Lakh = 100, 000).
# 5.	Kilometers_driven: The total kilometers driven in the car by the previous owner(s) in KM.
# 6.	Fuel_Type: The type of fuel used by the car. (Petrol, Diesel, Electric, CNG, LPG).
# 7.	Seller_type: The type of seller who is selling the car (Individual or a Dealer).
# 8.	Transmission: The type of transmission used by the car. (Automatic / Manual).
# 9.	Owner: Type of ownership.
# 10.	Mileage: The standard mileage offered by the car company in kmpl or km/kg.
# 11.	Engine: The displacement volume of the engine in CC.
# 12.	Max_power: The maximum power of the engine in bhp.
# 13.	Seats: The number of seats in the car.
# 14.	City: The location in which the car is being sold or is available for purchase (Cities).
# 15.	Postal_code: The postal code in which the car is being sold or is available for purchase.
# 16.	Sales_status: Status of used car sold or not (Y or N).

# %% [markdown]
# # REQUIRED LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"D:\Case Study_2.csv")

# %%
df.head()
# Out:
#    Sales_ID                          name  year  selling_price  km_driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#      fuel seller_type transmission         owner     mileage   engine  \
# 0  Diesel  Individual       Manual   First Owner   23.4 kmpl  1248 CC
# 1  Diesel  Individual       Manual  Second Owner  21.14 kmpl  1498 CC
# 2  Petrol  Individual       Manual   Third Owner   17.7 kmpl  1497 CC
# 3  Diesel  Individual       Manual   First Owner   23.0 kmpl  1396 CC
# 4  Petrol  Individual       Manual   First Owner   16.1 kmpl  1298 CC
#
#     max_power  seats      City  Postal_code Sales_status
# ...

# %% [markdown]
# # DATA INFO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7906 entries, 0 to 7905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales_ID       7906 non-null   int64
#  1   name           7906 non-null   object
#  2   year           7906 non-null   int64
#  3   selling_price  7906 non-null   int64
#  4   km_driven      7906 non-null   int64
#  5   fuel           7906 non-null   object
#  6   seller_type    7906 non-null   object
#  7   transmission   7906 non-null   object
#  8   owner          7906 non-null   object
#  9   mileage        7906 non-null   object
#  10  engine         7906 non-null   object
#  11  max_power      7906 non-null   object
#  12  seats          7906 non-null   int64
#  13  City           7906 non-null   object
#  14  Postal_code    7906 non-null   int64
#  15  Sales_status   7906 non-null   object
# dtypes: int64(6), object(10)
# memory usage: 988.4+ KB

# %% [markdown]
# # Shape of data

# %%
df.shape
# Out:
# (7906, 16)

# %%
df.columns
# Out:
# Index(['Sales_ID', 'name', 'year', 'selling_price', 'km_driven', 'fuel',
#        'seller_type', 'transmission', 'owner', 'mileage', 'engine',
#        'max_power', 'seats', 'City', 'Postal_code', 'Sales_status'],
#       dtype='object')

# %% [markdown]
# # Missing values

# %%
df.isnull().sum()
# Out:
# Sales_ID         0
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# seats            0
# City             0
# Postal_code      0
# Sales_status     0
# dtype: int64

# %% [markdown]
# # Descriptive statistics

# %%
df.describe()
# Out:
#           Sales_ID         year  selling_price     km_driven        seats  \
# count  7906.000000  7906.000000   7.906000e+03  7.906000e+03  7906.000000
# mean   4070.106248  2013.983936   6.498137e+05  6.918866e+04     5.416393
# std    2345.770159     3.863695   8.135827e+05  5.679230e+04     0.959208
# min       1.000000  1994.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2037.250000  2012.000000   2.700000e+05  3.500000e+04     5.000000
# 50%    4076.500000  2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    6102.000000  2017.000000   6.900000e+05  9.542500e+04     5.000000
# max    8128.000000  2020.000000   1.000000e+07  2.360457e+06    14.000000
#
#          Postal_code
# count    7906.000000
# mean   503806.024285
# std    205061.544757
# min    110039.000000
# 25%    391510.000000
# 50%    524225.000000
# 75%    680503.000000
# max    834008.000000

# %% [markdown]
# # STATISTICAL ANALYTSIS  : Hypothesis Testing

# %% [raw]
#     a)	You are a data analyst working for a car dealership company. Investigate whether there is a statistically significant difference in the distribution of the number of seats between cars with automatic and manual transmissions. Perform a hypothesis test to determine whether there is a significant difference in the number of seats for cars with automatic and manual transmissions.
#     Based on your analysis, provide insights to the management team about whether the number of seats is significantly different between cars with automatic and manual transmissions. This information will be useful in identifying which transmission type is more popular among customers and which features customers value the most. It will also help the company make informed decisions on inventory management and pricing strategies.

# %%
#solution

# %% [markdown]
# H0 --> There is no difference in the mean number of seats between cars with automatic and manual transmissions.
#
# H1 --> There is a difference in the mean number of seats between cars with automatic and manual transmissions.

# %% [markdown]
# # Independent T-test

# %%
df.groupby("transmission")["seats"].describe()
# Out:
#                count      mean       std  min  25%  50%  75%   max
# transmission
# Automatic     1041.0  5.237272  0.716827  4.0  5.0  5.0  5.0   8.0
# Manual        6865.0  5.443554  0.988009  2.0  5.0  5.0  5.0  14.0

# %% [markdown]
# Step-1: Test of Normality
#
# NO Need to check ,sample size is greater than 30
#
# Step-2 Test of variance Equality
#
# H0 --> The variance of popluation are equal
#
# H1 --> The variance of popluation are not equal

# %%
automatic_seats = df[df['transmission'] == 'Automatic']['seats']
manual_seats = df[df['transmission'] == 'Manual']['seats']

# %%
st.levene(automatic_seats,manual_seats)
# Out:
# LeveneResult(statistic=45.65848879649594, pvalue=1.5076146904294063e-11)

# %%
pvalue=1.5076146904294063e-11
alpha=0.05
if abs (pvalue) < abs(alpha):
    print('reject H0')
else:
    print('Accept H0')
# Out:
# reject H0

# %% [raw]
# The population variance are different

# %%
st.ttest_ind(automatic_seats,manual_seats,equal_var=False)
# Out:
# TtestResult(statistic=-8.180937812361945, pvalue=5.4468421426690085e-16, df=1704.0734411529777)

# %%
pvalue=5.4468421426690085e-16
alpha=0.05
if abs (pvalue) < abs(alpha):
    print('reject H0')
else:
    print('Accept H0')
# Out:
# reject H0

# %% [markdown]
# ##### Hence, we can conclude that there is a statistically significant difference in the distribution of the number of seats between cars with automatic and manual transmissions. This information is valuable for the management team to understand customer preferences and prioritize features in inventory management, pricing strategies, and marketing efforts.

# %% [raw]
#     b)	As a data analyst in a car dealership company, you are analyzing the company's sales data to identify any significant differences in the selling prices of cars based on the fuel type.  If there is a statistically significant difference in the selling price distribution for different fuel types, which fuel types have the highest and lowest selling prices? Your task is to perform an analysis of the data and report your findings to the management.
#
#     Based on your analysis, you will be able to provide insights on which fuel types are most popular among customers and which models are more expensive, helping the company make informed decisions on inventory and pricing strategies.

# %% [markdown]
# # One way ANOVA

# %% [markdown]
# H0 --> There is no significant difference in the means of selling prices among different fuel types.
#
# H1 --> There is a significant difference in the means of selling prices among different fuel types.

# %%
df.groupby("fuel")["selling_price"].describe()
# Out:
#          count           mean            std       min       25%       50%  \
# fuel
# CNG       52.0  317903.788462  101372.518867  120000.0  231250.0  330000.0
# Diesel  4299.0  802450.282624  915753.684639   45000.0  350000.0  550000.0
# LPG       35.0  210885.714286   79828.039976   54000.0  150000.0  200000.0
# Petrol  3520.0  472665.203125  631712.877861   29999.0  210000.0  350000.0
#
#              75%         max
# fuel
# CNG     392250.0    545000.0
# Diesel  800000.0   7200000.0
# LPG     275000.0    375000.0
# Petrol  550000.0  10000000.0

# %% [markdown]
# step-1 => Test of Normality
#
# H0 : population_data = normal
#
# H1 : population_data != normal

# %%
CNG=df[df["fuel"]=="CNG"]["selling_price"]
Diesel=df[df["fuel"]=="Diesel"]["selling_price"]
LPG=df[df["fuel"]=="LPG"]["selling_price"]
Petrol=df[df["fuel"]=="Petrol"]["selling_price"]

# %%
st.shapiro(CNG),st.shapiro(Diesel),st.shapiro(LPG),st.shapiro(Petrol)
# Out:
# (ShapiroResult(statistic=0.9634795188903809, pvalue=0.1107923611998558),
#  ShapiroResult(statistic=0.5905824303627014, pvalue=0.0),
#  ShapiroResult(statistic=0.9675596952438354, pvalue=0.3798074722290039),
#  ShapiroResult(statistic=0.43488091230392456, pvalue=0.0))

# %%
pvalue=0.1107923611998558
alpha=0.05
if abs (pvalue) < abs(alpha):
    print('reject H0')
else:
    print('Accept H0')
# Out:
# Accept H0

# %%
pvalue=0.0
alpha=0.05
if abs (pvalue) < abs(alpha):
    print('reject H0')
else:
    print('Accept H0')
# Out:
# reject H0

# %%
pvalue=0.3798074722290039
alpha=0.05
if abs (pvalue) < abs(alpha):
    print('reject H0')
else:
    print('Accept H0')
# Out:
# Accept H0

# %%
pvalue=0.0
alpha=0.05
if abs (pvalue) < abs(alpha):
    print('reject H0')
else:
    print('Accept H0')
# Out:
# reject H0

# %% [markdown]
# we can concluded that population data not follows normal
#
# step 2 Test of variance Equality
#
# H0: The variance of population are equal
#
# H1: Anyone of population variance is difference from others

# %%
st.levene(CNG,Diesel,LPG,Petrol)
# Out:
# LeveneResult(statistic=48.945864420404206, pvalue=2.463675999346852e-31)

# %%
pvalue=2.463675999346852e-31
alpha=0.05
if abs (pvalue) < abs(alpha):
    print('reject H0')
else:
    print('Accept H0')
# Out:
# reject H0

# %% [markdown]
# Hence,We can concluded that variance is different population

# %% [markdown]
# # kruskal Test

# %% [markdown]
# H0 : All median are equal
#
# H1 : Any two median are different

# %%
st.kruskal(CNG,Diesel,LPG,Petrol)
# Out:
# KruskalResult(statistic=892.8076695571675, pvalue=3.214271037253098e-193)

# %%
pvalue=3.214271037253098e-193
alpha=0.05
if abs (pvalue) < abs(alpha):
    print('reject H0')
else:
    print('Accept H0')
# Out:
# reject H0

# %% [markdown]
# hence we can concluded that median different

# %% [markdown]
#     I can conclude that there is a significant difference in the selling prices of cars based on the fuel type they use. Diesel cars tend to have higher prices than petrol, CNG, and LPG cars. Diesel models are more expensive, while LPG models are cheaper in selling price. This information can help me understand which fuel types are most popular among customers and which models are more expensive, helping me make informed decisions on inventory and pricing strategies.

# %% [markdown]
# # Data Visualization:

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# ### HISTOGRAM

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 15))


plt.subplot(3, 2, 1)
df['year'].hist(bins=20)
plt.title('Histogram of Manufacturing Year')
plt.xlabel('Year')
plt.ylabel('Frequency')


plt.subplot(3, 2, 2)
df['selling_price'].hist(bins=20)
plt.title('Histogram of Selling Price')
plt.xlabel('Price (INR Lakhs)')
plt.ylabel('Frequency')


plt.subplot(3, 2, 3)
df['km_driven'].hist(bins=20)
plt.title('Histogram of Kilometers Driven')
plt.xlabel('Kilometers Driven (KM)')
plt.ylabel('Frequency')


plt.subplot(3, 2, 4)
df['engine'].hist(bins=20)
plt.title('Histogram of Engine Size')
plt.xlabel('Engine Size (CC)')
plt.ylabel('Frequency')


plt.subplot(3, 2, 5)
df['max_power'].hist(bins=20)
plt.title('Histogram of Max Power')
plt.xlabel('Max Power (bhp)')
plt.ylabel('Frequency')


plt.subplot(3, 2, 6)
df['seats'].hist(bins=20)
plt.title('Histogram of Number of Seats')
plt.xlabel('Number of Seats')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHTS

# %% [markdown]
# ##### 1.Histogram of Manufacturing Year:
#
# The bulk of the vehicles were manufactured between 2005 and 2015.
#
#
# There is a sharp decline in frequency before 1995 and after 2015.

# %% [markdown]
# ##### 2.Histogram of Kilometers Driven:
#
# A high number of vehicles have driven less than 0.5 million kilometers.
#
#
#
# The frequency drastically decreases as the kilometers driven increases, indicating that fewer vehicles have higher mileage.

# %% [markdown]
# ##### 3.Histogram of Selling Price:
#
# Most vehicles have a selling price in the lower range, with the highest frequency for the lowest price bracket.
#
#
#
#
# There is a rapid decline in the number of vehicles as the price increases, suggesting that higher-priced vehicles are less common in this dataset.

# %% [markdown]
# ##### 4. Histogram of Engine Size:
#
# There is a wide range of engine sizes, with a concentration of smaller engine sizes.
#
#
#
# The frequency decreases as engine size increases, showing that larger engines are less common.

# %% [markdown]
# ##### 5.Histogram of Max Power:
#
# The data shows a spread of max power values with several peaks, indicating common power ratings for vehicles.
#
#
#
# There is a gradual decrease in frequency as max power increases, with very few vehicles having very high power ratings.

# %% [markdown]
# ##### 6.Histogram of Number of Seats:
#
# The majority of vehicles have either 5 or 7 seats.
#
#
#
# Vehicles with more than 8 seats are significantly less common, as indicated by the low frequency.

# %% [markdown]
# # BAR CHARTS

# %%
plt.figure(figsize=(20, 15))


plt.subplot(3, 2, 1)
df['fuel'].value_counts().plot(kind='bar')
plt.title('Bar Chart of Fuel Types')
plt.xlabel('Fuel Type')
plt.ylabel('Frequency')


plt.subplot(3, 2, 2)
df['seller_type'].value_counts().plot(kind='bar')
plt.title('Bar Chart of Seller Types')
plt.xlabel('Seller Type')
plt.ylabel('Frequency')


plt.subplot(3, 2, 3)
df['transmission'].value_counts().plot(kind='bar')
plt.title('Bar Chart of Transmission Types')
plt.xlabel('Transmission Type')
plt.ylabel('Frequency')

plt.subplot(3, 2, 4)
df['owner'].value_counts().plot(kind='bar')
plt.title('Bar Chart of Ownership Types')
plt.xlabel('Owner Type')
plt.ylabel('Frequency')

plt.subplot(3, 2, 5)
df['seats'].value_counts().plot(kind='bar')
plt.title('Bar Chart of Number of Seats')
plt.xlabel('Number of Seats')
plt.ylabel('Frequency')



plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHTS

# %% [markdown]
# ##### 1.Fuel Types:
#
# --Diesel and petrol are the most common fuel types, with diesel being slightly more prevalent.
#
#
# --CNG and LPG are much less common compared to diesel and petrol.

# %% [markdown]
# ##### 2.Transmission Types:
#
# Manual transmission vehicles greatly outnumber automatic transmission vehicles.

# %% [markdown]
# ##### 3.Seller Types:
#
# Individual sellers are the most common, significantly outnumbering dealers and trusted dealers.

# %% [markdown]
# ##### 4.Ownership Types:
#
# First owners make up the majority of the ownership type.
#
#
# Second owners are also present but in lower numbers, followed by third and fourth or above owners.
#
#
# Test drive cars are the least common.

# %% [markdown]
# ##### 5.Number of Seats:
#
#
# There is a small number of 7-seat vehicles, and very few vehicles have 2, 4, 6, 8, 10, 12, or 14 seats.

# %%
fuel_transmission = df.groupby(['transmission', 'fuel']).size().unstack()


fuel_transmission.plot(kind='bar', stacked=False, figsize=(10, 6))
plt.title('Comparison of Fuel Types Based on Transmission Type')
plt.xlabel('Transmission Type')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # INSIGHTS

# %% [markdown]
# Diesel and petrol are the most common fuels for manual transmission vehicles, with diesel being the most prevalent.
#
#
# For automatic transmissions, the frequencies are much lower, and while petrol is present, diesel is notably absent.
#
#
#
# CNG and LPG fuel types appear to be negligible or non-existent for these transmission

# %%
city_data = {
    'City': ['Mumbai', 'Delhi', 'Bangalore', 'Hyderabad', 'Chennai', 'Kolkata', 'Pune', 'Jaipur', 'Lucknow', 'Kanpur'],
    'Frequency': [100, 90, 80, 70, 60, 50, 40, 30, 20, 10]
}

df_city = pd.DataFrame(city_data)


colors = plt.cm.viridis(np.linspace(0, 1, len(df_city)))

plt.figure(figsize=(14, 7)) 
plt.bar(df_city['City'], df_city['Frequency'], color=colors)
plt.title('Bar Chart of Cities')
plt.xlabel('City')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # DISTRIBUTION PLOTS

# %%
plt.figure(figsize=(20, 10))


plt.subplot(2, 2, 1)
sns.histplot(df['year'], kde=True, color='skyblue')
plt.title('Distribution of Manufacturing Year')
plt.xlabel('Year')
plt.ylabel('Frequency')

plt.subplot(2, 2, 2)
sns.histplot(df['selling_price'], kde=True, color='olive')
plt.title('Distribution of Selling Price')
plt.xlabel('Selling Price')
plt.ylabel('Frequency')


plt.subplot(2, 2, 3)
sns.histplot(df['km_driven'], kde=True, color='coral')
plt.title('Distribution of Kilometers Driven')
plt.xlabel('Kilometers Driven')
plt.ylabel('Frequency')


plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHTS

# %% [markdown]
# ##### Manufacturing Year:
#
# The distribution shows that the frequency of cars increases for more recent manufacturing years, with a significant number of cars made after 2010.
#
#
# This suggests that the dataset likely contains a higher number of newer model cars.

# %% [markdown]
# ##### Selling Price:
#
# The distribution is right-skewed with most of the selling prices concentrated at the lower end, indicating that the dataset predominantly contains more affordable cars.
#
#
# There are few high-priced cars, which are likely to be luxury or premium models.

# %% [markdown]
# ##### Kilometers Driven:
#
# Similar to the selling price, the kilometers driven distribution is also right-skewed, with most cars having lower mileage.
#
#
#
# High-mileage cars are less common, suggesting that the dataset mostly consists of cars that have not been driven extensively.

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# ### SCATTER PLOT

# %%
#selling_price,km_driven

# %%
sns.scatterplot(x='selling_price',y='km_driven',hue='Sales_status',data=df)
# Out:
# <Axes: xlabel='selling_price', ylabel='km_driven'>

# %% [markdown]
# # heatmap

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])

plt.subplots(figsize=(12,7))
sns.heatmap(numeric_df.corr(), annot=True)

plt.show()

# %%
numeric_df = df.select_dtypes(include=[np.number]) 


mask = np.zeros_like(numeric_df.corr())
mask[np.triu_indices_from(mask)] = True

fig, ax = plt.subplots(figsize=(15, 5))
sns.heatmap(numeric_df.corr(), cmap='Set2', annot=True, mask=mask, ax=ax)
plt.show()

# %% [markdown]
# # INSIGHTS

# %% [markdown]
# ##### Year and Selling Price:
#
# There's a moderate positive correlation (0.41) between the year of the car and its selling price, indicating newer cars tend to sell for more.

# %% [markdown]
# ##### Year and Km Driven:
#
# There's a moderate negative correlation (-0.43) between the year of the car and the kilometers driven, suggesting that newer cars generally have less mileage.

# %% [markdown]
# ##### Selling Price and Km Driven:
#
# A negative correlation (-0.22) exists between selling price and kilometers driven, indicating that cars with higher mileage tend to have lower selling prices.

# %% [markdown]
# ##### Seats and Km Driven:
#
# There's a slight positive correlation (0.23) between the number of seats in a car and the kilometers driven, which could imply that larger vehicles (which often have more seats) are driven more.

# %% [markdown]
# ##### Seats and Selling Price:
#
# The correlation (0.042) is very low, suggesting there's no significant relationship between the number of seats and the selling price.

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df)
# Out:
# C:\Users\Admin\Anaconda3\conda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
